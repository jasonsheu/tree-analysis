# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('trees_2024.xlsx')

# %%
df
# Out:
#      Unnamed: 0          Tree Species#name                #img Tree/Site  \
# 0             0  Acacia rostellifera Benth  fu_tn824ir8zr2ika6      Tree
# 1             1                Aleppo pine  fu_cxez2mf2uh2ejm3      Tree
# 2             2                Aleppo Pine  fu_phygsa3t7afknn9      Tree
# 3             3                Aleppo Pine  fu_pnzhkj8m5evquxa      Tree
# 4             4                Aleppo Pine  fu_rwk7ekckz86gwxt      Tree
# ..          ...                        ...                 ...       ...
# 647         647                   Tree #26  fu_7atpbri35t8na8a      Tree
# 648         648                   Tree #27  fu_shswv8q45fv7fiq      Tree
# 649         649                   Tree #28  fu_qkn6jn3vezvrs35      Tree
# 650         650                   Tree #29  fu_br85v79uamsyi4s      Tree
# 651         651                   Tree #30  fu_t4kmzgx73wj64wz      Tree
#
#     Uploader   Student name              Email Fruit/Seed  \
# ...
