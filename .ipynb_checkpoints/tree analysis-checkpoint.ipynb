# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import scipy as sp
import matplotlib.pyplot as plt
from scipy import stats

# %%
trees = pd.read_csv('trees with stats.csv')
trees = trees[['Tree Species#name', 'Park Name','Fruit/Seed', 'CEI Score', 'CEI Index','Height (ft)', 'Circumference', 'Diameter', 'Acreage', 'Census Tract', 'Per Capita Income', 'Under 18','People Per Square Mile']]
trees = trees.drop(trees.tail(12).index)
trees = trees.replace({'Moderate': 'High/Very High'})
df = trees
df  = df.fillna(0)
df['CEI_Group'] = np.where(df['CEI Score'] >= 70, 'High_CEI', 'Low_CEI')
df['CEI_enc'] = np.where(df['CEI Score'] >= 70, 1, 0)
df['Per Capita Income'] = df['Per Capita Income'].str.replace(',','').astype(float)
df['Park Name'] = df['Park Name'].str.replace(r'Team \d$','')
num_trees = df.groupby('Park Name').count()[['Tree Species#name']].reset_index()
num_trees.columns = ['Park Name', 'Number of Trees']
tree_species = df.groupby('Park Name').nunique()[['Tree Species#name']].reset_index()
tree_species.columns = ['Park Name', 'Number of Unique Tree Species']
df = df.merge(num_trees, on = 'Park Name')
df = df.merge(tree_species, on = 'Park Name')
df = df.groupby('Park Name').mean()
df['Trees Per Acre'] = df['Number of Trees']/df['Acreage']


df.head()
# Out:
# C:\Users\jason\AppData\Local\Temp\ipykernel_29212\3184166624.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Park Name'] = df['Park Name'].str.replace(r'Team \d$','')
# C:\Users\jason\AppData\Local\Temp\ipykernel_29212\3184166624.py:17: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = df.groupby('Park Name').mean()
#                       CEI Score  Height (ft)  Circumference   Diameter  \
# Park Name
# Cherokee Point             61.0    25.330000      29.162500   9.266000
# Collier                    84.0    21.540541      44.891892  14.508919
# Dorothy Petway             25.0    27.264706      30.029412   9.735294
# Edward Tyler Cramer        77.0    16.384615      16.903846   5.846154
# Gershwin                    0.0    38.978559      59.400000  19.056036
#
#                       Acreage  Census Tract  Per Capita Income  Under 18  \
# Park Name
# Cherokee Point           1.48         24.01            26947.0      0.27
# Collier                  5.70         74.02            40314.0      0.23
# Dorothy Petway           2.72         36.01            15462.0      0.35
# Edward Tyler Cramer      2.98         91.07            40595.0      0.10
# Gershwin                 5.39         85.02            38286.0      0.19
#
#                       People Per Square Mile  CEI_enc  Number of Trees  \
# Park Name
# Cherokee Point                       19314.0      0.0             40.0
# Collier                              12499.4      1.0             37.0
# Dorothy Petway                        9654.9      0.0             34.0
# Edward Tyler Cramer                  16312.4      1.0             26.0
# Gershwin                              6486.3      0.0            111.0
#
#                       Number of Unique Tree Species  Trees Per Acre
# Park Name
# Cherokee Point                                 10.0       27.027027
# Collier                                        23.0        6.491228
# Dorothy Petway                                  9.0       12.500000
# Edward Tyler Cramer                             4.0        8.724832
# Gershwin                                       11.0       20.593692

# %%
def t_test(col):
    '''
    Run a t-test on a column from the tree data collected and return the results
    '''
    # Split data into High CEI and Low CEI groups
    high_cei_diameters = df[df['CEI_Group'] == 'High_CEI'][col].tolist()
    low_cei_diameters = df[df['CEI_Group'] == 'Low_CEI'][col].tolist()

    # T-test for tree diameter
    t_stat_diameter, p_value_diameter = stats.ttest_ind(high_cei_diameters, low_cei_diameters, equal_var=False)
    return(f"T-Test for Tree {col}: t-statistic={t_stat_diameter}, p-value={p_value_diameter}")
for i in ['Height (ft)', 'Diameter', 'Circumference']:
    print(t_test(i))
# Out:
# T-Test for Tree Height (ft): t-statistic=4.195354134427296, p-value=3.246534449215116e-05
# T-Test for Tree Diameter: t-statistic=7.1532061547137955, p-value=2.673198507102167e-12
# T-Test for Tree Circumference: t-statistic=7.122874058048242, p-value=3.341695315002012e-12

# %%
list_features = ['CEI Score', 'Height (ft)', 'Circumference', 'Diameter','Per Capita Income','Number of Trees', 'Number of Unique Tree Species','Trees Per Acre', 'Acreage']
for i in ['pearson','spearman','kendall']:
    correlation_matrix = df[list_features].corr(method=i)
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title("Correlation Matrix Heatmap")
    plt.show()

# %%
trees.columns = ['tree', 'park', 'fruit or nut', 'CEI score', 'CEI index', 'height (ft)', 'circumference','diameter','acreage', 'census tract', 'per capita income', 'under 18','people per square mile']

# %%
print("High CEI Diameters Summary:")
print(high_cei_diameters.describe())

print("\nLow CEI Diameters Summary:")
print(low_cei_diameters.describe())

print("\nHigh CEI Trees Summary:")
print(high_cei_trees.describe())

print("\nLow CEI Trees Summary:")
print(low_cei_trees.describe())
# Out:
# High CEI Diameters Summary:
# count    328.000000
# mean      21.562530
# std       14.630745
# min        0.000000
# 25%       12.000000
# 50%       19.000000
# 75%       29.000000
# max      121.340000
# Name: Diameter, dtype: float64
#
# Low CEI Diameters Summary:
# count    312.000000
# mean      13.757663
# std       11.583456
# min        0.000000
# 25%        4.805000
# 50%       10.000000
# 75%       20.040000
# max       62.500000
# Name: Diameter, dtype: float64
#
# High CEI Trees Summary:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 8
#       5 print(low_cei_diameters.describe())
#       7 print("\nHigh CEI Trees Summary:")
# ----> 8 print(high_cei_trees.describe())
#      10 print("\nLow CEI Trees Summary:")
#      11 print(low_cei_trees.describe())
#
# NameError: name 'high_cei_trees' is not defined

# %%
def fruit_seed_encode(data):
    if data == 'Fruit' or data == 'Nut':
        return 1
    else:
        return 0
trees['fruit or nut'] = trees['fruit or nut'].apply(fruit_seed_encode).astype(int)
trees
# Out:
#                     tree                   park  fruit or nut  CEI score  \
# 0       Brazilian Pepper  Cherokee Point Team 1             1       61.0
# 1    California Sycamore  Cherokee Point Team 1             1       61.0
# 2      African Fern Pine  Cherokee Point Team 1             1       61.0
# 3    California Sycamore  Cherokee Point Team 1             1       61.0
# 4    California Sycamore  Cherokee Point Team 1             1       61.0
# ..                   ...                    ...           ...        ...
# 639    Lemon scented gum  Villa La Jolla Team 3             1       87.0
# 640    Lemon scented gum  Villa La Jolla Team 3             1       87.0
# 641             Blue Gum  Villa La Jolla Team 3             0       87.0
# 642    Lemon scented gum  Villa La Jolla Team 3             1       87.0
# 643         Brisbane box  Villa La Jolla Team 3             1       87.0
#
#           CEI index  height (ft)  circumference  diameter  acreage  \
# 0    High/Very High         33.0           34.0     10.82     1.48
# 1    High/Very High         37.5           28.0      8.91     1.48
# 2    High/Very High         24.0           27.0      8.59     1.48
# 3    High/Very High         30.0           22.0      7.00     1.48
# 4    High/Very High         37.5           28.0      8.91     1.48
# ..              ...          ...            ...       ...      ...
# 639  High/Very High         67.0           86.0     27.39     5.79
# 640  High/Very High         50.0           52.0     16.56     5.79
# 641  High/Very High         52.0           58.0     18.47     5.79
# 642  High/Very High         54.0           72.0     22.93     5.79
# 643  High/Very High         40.0           64.0     20.38     5.79
#
#      census tract per capita income  under 18  people per square mile
# 0           24.01             26947      0.27                 19314.0
# 1           24.01             26947      0.27                 19314.0
# 2           24.01             26947      0.27                 19314.0
# 3           24.01             26947      0.27                 19314.0
# 4           24.01             26947      0.27                 19314.0
# ..            ...               ...       ...                     ...
# 639         83.62             51313      0.20                 10164.4
# 640         83.62             51313      0.20                 10164.4
# 641         83.62             51313      0.20                 10164.4
# 642         83.62             51313      0.20                 10164.4
# 643         83.62             51313      0.20                 10164.4
#
# [644 rows x 13 columns]

# %%
trees['tree'].value_counts().head(20)
# Out:
# Blue Gum               99
# Lemon Scented Gum      46
# Torrey Pine            34
# African Fern Pine      25
# Aleppo Pine            22
# Chinese flame tree     21
# Lemon scented gum      20
# Brisbane Box           18
# Peruvian Pepper        17
# Peruvian Pine          16
# Tipuana                15
# London Plane           14
# brisbane box           13
# Chinese Flame          12
# Oak                    11
# Bronze Loquat          10
# California Sycamore    10
# pine                    9
# Brazilian Pepper        8
# CarrotWood              8
# Name: tree, dtype: int64

# %%
trees.head()
# Out:
#                   tree                   park  fruit or nut  CEI score  \
# 0     Brazilian Pepper  Cherokee Point Team 1             1       61.0
# 1  California Sycamore  Cherokee Point Team 1             1       61.0
# 2    African Fern Pine  Cherokee Point Team 1             1       61.0
# 3  California Sycamore  Cherokee Point Team 1             1       61.0
# 4  California Sycamore  Cherokee Point Team 1             1       61.0
#
#         CEI index  height (ft)  circumference  diameter  acreage  \
# 0  High/Very High         33.0           34.0     10.82     1.48
# 1  High/Very High         37.5           28.0      8.91     1.48
# 2  High/Very High         24.0           27.0      8.59     1.48
# 3  High/Very High         30.0           22.0      7.00     1.48
# 4  High/Very High         37.5           28.0      8.91     1.48
#
#    census tract per capita income  under 18  people per square mile
# 0         24.01             26947      0.27                 19314.0
# 1         24.01             26947      0.27                 19314.0
# 2         24.01             26947      0.27                 19314.0
# 3         24.01             26947      0.27                 19314.0
# 4         24.01             26947      0.27                 19314.0

# %%
trees['per capita income'] = trees['per capita income'].str.replace(',','', regex=True)
trees['per capita income'] = trees['per capita income'].fillna(0)
trees['per capita income'] = trees['per capita income'].astype(int)

# %%
trees_grouped = trees.groupby('park').mean()
trees_grouped['count'] = trees.groupby('park').count()['tree']
trees_grouped['fruit or nut'] = trees.groupby('park').sum()['fruit or nut']/trees_grouped['count']
trees_grouped.head(13)
# Out:
# C:\Users\jason\AppData\Local\Temp\ipykernel_25144\1617054194.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   trees_grouped = trees.groupby('park').mean()
# C:\Users\jason\AppData\Local\Temp\ipykernel_25144\1617054194.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   trees_grouped['fruit or nut'] = trees.groupby('park').sum()['fruit or nut']/trees_grouped['count']
#                             fruit or nut  CEI score  height (ft)  \
# park
# Cherokee Point Team 1           0.916667       61.0    31.625000
# Cherokee Point Team 2           0.230769       61.0    28.538462
# Cherokee Point Team 3           0.733333       61.0    17.513333
# Collier Team 1                  0.315789       84.0    16.947368
# Collier Team 2                  0.722222       84.0    26.388889
# Dorothy Petway                  0.470588       25.0    27.264706
# Edward Tyler Cramer Team 2      1.000000       77.0    16.384615
# Gershwin Team 1                 0.666667        NaN    40.736842
# Gershwin Team 2                 0.000000        NaN    37.122593
# Grant Hill Team 1               0.833333       43.0    33.458333
# Grant Hill Team 2               0.555556       43.0    40.111111
# John F Kennedy                  0.033333       30.0    34.533333
# Mesa Viking                     1.000000       70.0    76.600000
#
#                             circumference   diameter  acreage  census tract  \
# park
# Cherokee Point Team 1           32.875000  10.463333     1.48         24.01
# Cherokee Point Team 2           33.461538  10.692308     1.48         24.01
# Cherokee Point Team 3           22.466667   7.072000     1.48         24.01
# Collier Team 1                  45.631579  14.947368     5.70         74.02
# Collier Team 2                  44.111111  14.046111     5.70         74.02
# Dorothy Petway                  30.029412   9.735294     2.72         36.01
# Edward Tyler Cramer Team 2      16.903846   5.846154     2.98         91.07
# Gershwin Team 1                 48.192982  15.628421     5.39         85.02
# Gershwin Team 2                 71.229630  22.674074     5.39         85.02
# Grant Hill Team 1               71.530833  30.491667     2.65         48.00
# Grant Hill Team 2              116.222222  37.000000     2.65         48.00
# John F Kennedy                  26.633000   4.238700     3.60        156.02
# Mesa Viking                     66.062500  21.022500     6.63         83.52
#
#                             per capita income  under 18  \
# park
# Cherokee Point Team 1                 26947.0      0.27
# Cherokee Point Team 2                 26947.0      0.27
# Cherokee Point Team 3                 26947.0      0.27
# Collier Team 1                        40314.0      0.23
# Collier Team 2                        40314.0      0.23
# Dorothy Petway                        15462.0      0.35
# Edward Tyler Cramer Team 2            40595.0      0.10
# Gershwin Team 1                       38286.0      0.19
# Gershwin Team 2                       38286.0      0.19
# Grant Hill Team 1                     18087.0      0.22
# Grant Hill Team 2                     18087.0      0.22
# John F Kennedy                        41640.0      0.20
# Mesa Viking                           28111.0      0.24
#
#                             people per square mile  count
# park
# Cherokee Point Team 1                      19314.0     12
# Cherokee Point Team 2                      19314.0     13
# Cherokee Point Team 3                      19314.0     15
# Collier Team 1                             12499.4     19
# Collier Team 2                             12499.4     18
# Dorothy Petway                              9654.9     34
# Edward Tyler Cramer Team 2                 16312.4     26
# Gershwin Team 1                             6486.3     57
# Gershwin Team 2                             6486.3     54
# Grant Hill Team 1                          17956.7     12
# Grant Hill Team 2                          17956.7      9
# John F Kennedy                              1609.8     30
# Mesa Viking                                15688.7     40

# %%
trees_grouped.fillna(0, inplace=True)

# %%
g = sns.lmplot(x='CEI score', y='per capita income', data=trees_grouped).set(title='CEI Score vs Per Capita Income')

def annotate(data, **kws):
    r, p = sp.stats.pearsonr(data['CEI score'], data['per capita income'])
    ax = plt.gca()
    ax.text(.05, .8, 'r={:.2f}, p={:.2g}'.format(r, p),
            transform=ax.transAxes)
    
g.map_dataframe(annotate)
g.set( xlabel = "CEI Score", ylabel = "Per Capita Income")

# %%
g = sns.lmplot(x='CEI score', y='diameter', data=trees_grouped).set(title='CEI score vs Diameter as a Proxy for Shade')

def annotate(data, **kws):
    r, p = sp.stats.pearsonr(data['CEI score'], data['diameter'])
    ax = plt.gca()
    ax.text(.05, .8, 'r={:.2f}, p={:.2g}'.format(r, p),
            transform=ax.transAxes)
    
g.map_dataframe(annotate)
g.set( xlabel = "CEI score", ylabel = "Diameter")

# %%
g = sns.lmplot(x='per capita income', y='count', data=trees_grouped).set(title='Per Capita Income vs Number of Trees in Each Park')

def annotate(data, **kws):
    r, p = sp.stats.pearsonr(data['per capita income'], data['count'])
    ax = plt.gca()
    ax.text(.05, .8, 'r={:.2f}, p={:.2g}'.format(r, p),
            transform=ax.transAxes)
    
g.map_dataframe(annotate)
g.set( xlabel = "Per Capita Income", ylabel = "Number of Trees")

# %%
trees.groupby('CEI index')

# %%
ax = trees.groupby('CEI index').count().plot.bar(y='tree', rot=0, label='Trees')

ax.set_xlabel('CEI Index')
ax.set_ylabel('Number of Trees')
# Out:
# Text(0, 0.5, 'Number of Trees')

# %%
temp = trees['CEI score'].value_counts().index.tolist()
temp2 = trees['CEI score'].value_counts().tolist()
s = pd.Series(temp, temp2)
s.hist()
# Out:
# <Axes: >

# %%
trees.reset_index()
# Out:
#      index                 tree                   park  fruit or nut  \
# 0        0     Brazilian Pepper  Cherokee Point Team 1             1
# 1        1  California Sycamore  Cherokee Point Team 1             1
# 2        2    African Fern Pine  Cherokee Point Team 1             1
# 3        3  California Sycamore  Cherokee Point Team 1             1
# 4        4  California Sycamore  Cherokee Point Team 1             1
# ..     ...                  ...                    ...           ...
# 639    639    Lemon scented gum  Villa La Jolla Team 3             1
# 640    640    Lemon scented gum  Villa La Jolla Team 3             1
# 641    641             Blue Gum  Villa La Jolla Team 3             0
# 642    642    Lemon scented gum  Villa La Jolla Team 3             1
# 643    643         Brisbane box  Villa La Jolla Team 3             1
#
#      CEI score       CEI index  height (ft)  circumference  diameter  acreage  \
# 0         61.0  High/Very High         33.0           34.0     10.82     1.48
# 1         61.0  High/Very High         37.5           28.0      8.91     1.48
# 2         61.0  High/Very High         24.0           27.0      8.59     1.48
# 3         61.0  High/Very High         30.0           22.0      7.00     1.48
# 4         61.0  High/Very High         37.5           28.0      8.91     1.48
# ..         ...             ...          ...            ...       ...      ...
# 639       87.0  High/Very High         67.0           86.0     27.39     5.79
# 640       87.0  High/Very High         50.0           52.0     16.56     5.79
# 641       87.0  High/Very High         52.0           58.0     18.47     5.79
# 642       87.0  High/Very High         54.0           72.0     22.93     5.79
# 643       87.0  High/Very High         40.0           64.0     20.38     5.79
#
#      census tract  per capita income  under 18  people per square mile
# 0           24.01              26947      0.27                 19314.0
# 1           24.01              26947      0.27                 19314.0
# 2           24.01              26947      0.27                 19314.0
# 3           24.01              26947      0.27                 19314.0
# 4           24.01              26947      0.27                 19314.0
# ..            ...                ...       ...                     ...
# 639         83.62              51313      0.20                 10164.4
# 640         83.62              51313      0.20                 10164.4
# 641         83.62              51313      0.20                 10164.4
# 642         83.62              51313      0.20                 10164.4
# 643         83.62              51313      0.20                 10164.4
#
# [644 rows x 14 columns]

# %%
def CEI_encode(cei):
    if cei == 'High/Very High':
        return 1
    else:
        return 0

trees['CEI index'] = trees['CEI index'].apply(CEI_encode)
trees
# Out:
#                     tree                   park  fruit or nut  CEI score  \
# 0       Brazilian Pepper  Cherokee Point Team 1             1       61.0
# 1    California Sycamore  Cherokee Point Team 1             1       61.0
# 2      African Fern Pine  Cherokee Point Team 1             1       61.0
# 3    California Sycamore  Cherokee Point Team 1             1       61.0
# 4    California Sycamore  Cherokee Point Team 1             1       61.0
# ..                   ...                    ...           ...        ...
# 639    Lemon scented gum  Villa La Jolla Team 3             1       87.0
# 640    Lemon scented gum  Villa La Jolla Team 3             1       87.0
# 641             Blue Gum  Villa La Jolla Team 3             0       87.0
# 642    Lemon scented gum  Villa La Jolla Team 3             1       87.0
# 643         Brisbane box  Villa La Jolla Team 3             1       87.0
#
#      CEI index  height (ft)  circumference  diameter  acreage  census tract  \
# 0            1         33.0           34.0     10.82     1.48         24.01
# 1            1         37.5           28.0      8.91     1.48         24.01
# 2            1         24.0           27.0      8.59     1.48         24.01
# 3            1         30.0           22.0      7.00     1.48         24.01
# 4            1         37.5           28.0      8.91     1.48         24.01
# ..         ...          ...            ...       ...      ...           ...
# 639          1         67.0           86.0     27.39     5.79         83.62
# 640          1         50.0           52.0     16.56     5.79         83.62
# 641          1         52.0           58.0     18.47     5.79         83.62
# 642          1         54.0           72.0     22.93     5.79         83.62
# 643          1         40.0           64.0     20.38     5.79         83.62
#
#      per capita income  under 18  people per square mile
# 0                26947      0.27                 19314.0
# 1                26947      0.27                 19314.0
# 2                26947      0.27                 19314.0
# 3                26947      0.27                 19314.0
# 4                26947      0.27                 19314.0
# ..                 ...       ...                     ...
# 639              51313      0.20                 10164.4
# 640              51313      0.20                 10164.4
# 641              51313      0.20                 10164.4
# 642              51313      0.20                 10164.4
# 643              51313      0.20                 10164.4
#
# [644 rows x 13 columns]

# %%
X = trees[['fruit or nut', 'CEI score', 'height (ft)','circumference', 'diameter','acreage']]
X= X.fillna(0)
y = trees['CEI index']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
clf = LogisticRegression(random_state=0).fit(X_train, y_train)

preds = clf.predict(X_test)

# %%
total = 0
for pred, label in zip(preds, y_test):
    if pred == label:
        total += 1
total/len(preds)
# Out:
# 0.7628865979381443

# %%
trees.plot.scatter('CEI score', 'CEI index')
# Out:
# <Axes: xlabel='CEI score', ylabel='CEI index'>

# %% [markdown]
# group by CEI score/index and number of trees in each bin, bar graph
#
# get more destrictive graphs
#
# group by CEI index, see what kinda trees are in both categories
